# %%
print("Session Active")

# %%
emp_data = [
    (100,'Hari',60000),
    (101,'rushi',55000),
    (102,'Ravi',50000),
    (103,'Rajesh',45000),
    (104,'Rakesh',40000),
    (105,'Raj',35000)
]
emp_cols = ['Emp_ID','Emp_Name','Salary']

emp_df = spark.createDataFrame(data=emp_data,schema=emp_cols)
display(emp_df)
